# %%
import os, random, numpy as np
from PIL import Image
import torchvision.transforms as transforms

# -------------------------------------------------------------------
# 1. Three-level augmentation presets
# -------------------------------------------------------------------
LEVEL_CONFIG = {
    1: {  # light augmentation
        "geo_prob": 0.30,
        "angle_range": 15,
        "color_prob": 0.30,
        "bright_range": (0.9, 1.1),
        "contrast_range": (0.9, 1.1),
        "saturation_range": (0.9, 1.1),
        "hue": 0.05,
        "noise_prob": 0.30,
        "noise_std": 5,
    },
    2: {  # medium augmentation  (matches the training script default)
        "geo_prob": 0.50,
        "angle_range": 30,
        "color_prob": 0.50,
        "bright_range": (0.8, 1.2),
        "contrast_range": (0.8, 1.2),
        "saturation_range": (0.8, 1.2),
        "hue": 0.10,
        "noise_prob": 0.50,
        "noise_std": 15,
    },
    3: {  # heavy augmentation
        "geo_prob": 0.80,
        "angle_range": 45,
        "color_prob": 0.80,
        "bright_range": (0.7, 1.3),
        "contrast_range": (0.7, 1.3),
        "saturation_range": (0.7, 1.3),
        "hue": 0.20,
        "noise_prob": 0.80,
        "noise_std": 25,
    },
}

# -------------------------------------------------------------------
# 2.  Helper: add Gaussian noise
# -------------------------------------------------------------------
def add_noise(img: Image.Image, std: float) -> Image.Image:
    """Add Gaussian noise with standard deviation `std` to an RGB image."""
    arr   = np.array(img).astype(np.float32)
    noise = np.random.normal(0, std, arr.shape)
    arr   = np.clip(arr + noise, 0, 255).astype(np.uint8)
    return Image.fromarray(arr)

# -------------------------------------------------------------------
# 3.  Apply one random augmentation level to a single PIL image
# -------------------------------------------------------------------
def augment_image(img: Image.Image, level: int = 2) -> Image.Image:
    """
    Parameters
    ----------
    img   : PIL.Image
    level : int   {1|2|3}. 1 = weak, 2 = medium, 3 = strong.
    """
    cfg = LEVEL_CONFIG[level]
    out = img.copy()

    # -- geometric transforms ----------------------------------------
    if random.random() < cfg["geo_prob"]:
        angle = random.uniform(-cfg["angle_range"], cfg["angle_range"])
        out   = out.rotate(angle, expand=True)
    if random.random() < cfg["geo_prob"]:
        out = out.transpose(Image.FLIP_LEFT_RIGHT)
    if random.random() < cfg["geo_prob"]:
        out = out.transpose(Image.FLIP_TOP_BOTTOM)

    # -- colour jitter ------------------------------------------------
    if random.random() < cfg["color_prob"]:
        jitter = transforms.ColorJitter(
            brightness = cfg["bright_range"],
            contrast   = cfg["contrast_range"],
            saturation = cfg["saturation_range"],
            hue        = cfg["hue"],
        )
        out = jitter(out)

    # -- Gaussian noise ----------------------------------------------
    if random.random() < cfg["noise_prob"]:
        out = add_noise(out, std=cfg["noise_std"])

    return out

# -------------------------------------------------------------------
# 4.  Loop over an ImageFolder-style directory and save augmented JPGs
# -------------------------------------------------------------------
def process_dataset_folder(input_root: str, output_root: str, level: int = 2) -> None:
    """
    Recursively iterate through `input_root`, apply augment_image(), and
    write new files to a mirrored folder tree rooted at `output_root`.

    Output filename format: <original_name>_L<level>.jpg
    """
    for dir_path, _, files in os.walk(input_root):
        rel_subdir = os.path.relpath(dir_path, input_root)
        target_dir = os.path.join(output_root, rel_subdir)
        os.makedirs(target_dir, exist_ok=True)

        for fname in files:
            if not fname.lower().endswith(".jpg"):
                continue
            src = os.path.join(dir_path, fname)
            try:
                img = Image.open(src).convert("RGB")
            except Exception:
                continue

            aug  = augment_image(img, level)
            stem, ext = os.path.splitext(fname)
            dst  = os.path.join(target_dir, f"{stem}_L{level}{ext}")
            aug.save(dst, "JPEG")
            print(f"Saved {dst}")

# -------------------------------------------------------------------
# 5.  Example CLI usage
# -------------------------------------------------------------------
if __name__ == "__main__":
    input_dataset  = "/path/to/train"
    output_dataset = "/path/to/train_aug"

    # Choose one or more levels to generate:
    process_dataset_folder(input_dataset, output_dataset, level=1)  # light
    process_dataset_folder(input_dataset, output_dataset, level=2)  # medium
    process_dataset_folder(input_dataset, output_dataset, level=3)  # heavy
# Out:
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/638_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/604_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/176_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/610_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/406_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/412_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/374_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/228_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/214_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/572_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/566_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/200_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/758_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/770_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/002_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/003_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/765_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/771_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/759_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/201_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/215_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/229_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/413_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/375_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/361_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/407_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/349_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/177_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/611_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/605_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/163_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/639_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/188_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/613_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/161_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/388_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/439_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/377_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/411_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/405_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/363_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/559_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/203_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/571_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/029_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/767_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/001_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/015_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/014_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/766_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/564_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/558_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/404_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/362_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/376_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/410_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/160_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/606_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/612_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/174_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/148_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/616_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/164_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/158_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/399_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/428_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/560_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/212_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/574_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/548_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/762_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/776_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/010_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/039_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/777_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/011_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/763_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/549_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/213_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/561_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/207_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/429_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/367_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/401_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/373_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/398_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/159_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/171_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/617_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/167_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/601_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/615_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/629_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/403_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/365_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/371_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/417_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/577_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/211_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/205_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/239_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/013_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/775_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/761_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/007_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/749_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/748_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/760_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/006_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/774_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/238_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/562_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/210_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/358_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/364_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/614_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/172_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/166_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/600_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/199_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/129_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/101_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/667_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/673_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/115_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/459_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/303_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/317_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/471_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/288_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/539_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/511_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/277_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/263_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/505_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/049_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/075_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/707_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/706_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/060_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/074_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/712_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/048_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/262_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/510_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/538_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/289_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/316_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/470_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/464_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/302_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/458_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/672_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/100_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/699_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/670_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/664_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/472_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/314_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/466_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/506_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/260_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/738_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/062_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/710_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/076_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/711_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/077_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/705_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/275_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/507_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/249_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/473_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/315_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/329_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/665_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/103_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/117_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/671_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/659_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/675_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/113_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/107_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/661_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/649_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/488_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/305_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/503_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/271_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/259_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/098_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/701_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/073_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/715_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/072_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/714_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/700_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/066_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/099_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/258_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/516_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/270_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/264_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/502_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/462_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/304_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/310_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/489_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/648_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/106_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/660_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/112_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture/689_aug.jpg
# 已保存增强图片: /Users/yaogunzhishen/Desktop/数据扰动后train/Agriculture